# %%
import nltk
nltk.download('punkt')
nltk.download('tagsets')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %% [markdown]
# # Part-of-speech tagging (POS)

# %%
# getting help about a specific category
nltk.help.upenn_tagset('JJ')
# Out:
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...

# %%
nltk.help.upenn_tagset('VB')
# Out:
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...

# %%
# text in English
text1 = """Hello Everybody. Welcome to the NLP class, hope you enjoy it a lot. Remember to do all your activities and assign homework. Have a nice day!"""
text2 = "Ethics are built right into the ideals and objectives of the United Nations "
text3 = "To be or not to be"
text4 = '"Ethics are built right into the ideals and objectives of the United Nations" \
#UNSG #UN @NY Society for Ethical Culture bit.ly/2guVelr'
text5 = "children shouldn't drink a sugary drink before bed."
text6 = "This is the 1st sentence. A gallon of milk in the U.S. costs $2.99. Is this the 3rd sentence? Yes, it is!"

# %%
# texto en Español
texto1 = """Hola a todos. Bienvenidos a la clase de NLP, ojalá disfruten la mataeria. Recuerden realizar todas las actividades y hacer los ejercicios propuestos. Que pasen un feliz día!"""

# %%
text_token1 = nltk.word_tokenize(text1)
text_token2 = nltk.word_tokenize(text2)
text_token3 = nltk.word_tokenize(text3)
text_token4 = nltk.word_tokenize(text4)
text_token5 = nltk.word_tokenize(text5)
text_token6 = nltk.word_tokenize(text6)

# %%
text_token1 = nltk.word_tokenize(texto1)

# %%
print(nltk.pos_tag(text_token1))
print(nltk.pos_tag(text_token2))
print(nltk.pos_tag(text_token3))
print(nltk.pos_tag(text_token4))
print(nltk.pos_tag(text_token5))
print(nltk.pos_tag(text_token6))
# Out:
# [('Hello', 'NNP'), ('Everybody', 'NNP'), ('.', '.'), ('Welcome', 'NNP'), ('to', 'TO'), ('the', 'DT'), ('NLP', 'NNP'), ('class', 'NN'), (',', ','), ('hope', 'VBP'), ('you', 'PRP'), ('enjoy', 'VBP'), ('it', 'PRP'), ('a', 'DT'), ('lot', 'NN'), ('.', '.'), ('Remember', 'NNP'), ('to', 'TO'), ('do', 'VB'), ('all', 'DT'), ('your', 'PRP$'), ('activities', 'NNS'), ('and', 'CC'), ('assign', 'NN'), ('homework', 'NN'), ('.', '.'), ('Have', 'VBP'), ('a', 'DT'), ('nice', 'JJ'), ('day', 'NN'), ('!', '.')]
# [('Ethics', 'NNS'), ('are', 'VBP'), ('built', 'VBN'), ('right', 'RB'), ('into', 'IN'), ('the', 'DT'), ('ideals', 'NNS'), ('and', 'CC'), ('objectives', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('United', 'NNP'), ('Nations', 'NNPS')]
# [('To', 'TO'), ('be', 'VB'), ('or', 'CC'), ('not', 'RB'), ('to', 'TO'), ('be', 'VB')]
# ...

# %%
print(nltk.pos_tag(text_token1))
# Out:
# [('Hola', 'NNP'), ('a', 'DT'), ('todos', 'NN'), ('.', '.'), ('Bienvenidos', 'VB'), ('a', 'DT'), ('la', 'JJ'), ('clase', 'NN'), ('de', 'FW'), ('NLP', 'NNP'), (',', ','), ('ojalá', 'RB'), ('disfruten', 'JJ'), ('la', 'NN'), ('mataeria', 'NN'), ('.', '.'), ('Recuerden', 'NNP'), ('realizar', 'NN'), ('todas', 'NN'), ('las', 'NNS'), ('actividades', 'IN'), ('y', 'JJ'), ('hacer', 'NN'), ('los', 'NN'), ('ejercicios', 'JJ'), ('propuestos', 'NN'), ('.', '.'), ('Que', 'NNP'), ('pasen', 'VBD'), ('un', 'JJ'), ('feliz', 'JJ'), ('día', 'NN'), ('!', '.')]

# %% [markdown]
# # Syntactic parsing
